# %% [markdown]
# # Transformação de dados - organizando o match history
#
# Do jeito que está nosso dataset, fica difícil de fazer consultas mais elaboradas, como
# * Qual campeão foi o mais banido
# * Qual o campeão foi o mais escolhido
# * Quais campeões tiveram mais vitórias
# * Com qual campeão cada player se deu melhor
#
# Então para isso, irei aplicar algumas transformações de dados para que possamos fazer essas consultas futuramente

# %%
import pandas as pd

df = pd.read_json('matches.json')

# %% [markdown]
# Visualizando nosso dataset

# %%
df.head()
# Out:
#         date  patch         team_1 team_2 winner_team  team_1_ban_1  \
# 0 2022-10-31  12.18          Gen.G    DRX         DRX  Heimerdinger
# 1 2022-10-30  12.18          Gen.G    DRX         DRX  Heimerdinger
# 2 2022-10-30  12.18            DRX  Gen.G         DRX        Lucian
# 3 2022-10-30  12.18          Gen.G    DRX       Gen.G  Heimerdinger
# 4 2022-10-24  12.18  EDward Gaming    DRX         DRX  Heimerdinger
#
#   team_1_ban_2 team_1_ban_3  team_1_ban_4 team_1_ban_5  ... team_1_player_1  \
# 0        Akali       Aatrox  Renata Glasc        Karma  ...           Doran
# 1        Sylas       Aatrox       Camille       Gragas  ...           Doran
# 2       Singed         Ryze          Gnar      Camille  ...          Kingen
# 3        Akali       Aatrox          Ashe        Karma  ...           Doran
# 4       Aatrox      Caitlyn       Kalista        Varus  ...         Flandre
#
#   team_1_player_2 team_1_player_3 team_1_player_4 team_1_player_5  \
# 0          Peanut           Chovy           Ruler         Lehends
# 1          Peanut           Chovy           Ruler         Lehends
# 2          Pyosik            Zeka            Deft           BeryL
# 3          Peanut           Chovy           Ruler         Lehends
# 4          JieJie           Scout           Viper           Meiko
#
#   team_2_player_1 team_2_player_2 team_2_player_3 team_2_player_4  \
# 0          Kingen          Pyosik            Zeka            Deft
# 1          Kingen          Pyosik            Zeka            Deft
# 2           Doran          Peanut           Chovy           Ruler
# 3          Kingen          Pyosik            Zeka            Deft
# 4          Kingen          Pyosik            Zeka            Deft
#
#   team_2_player_5
# 0           BeryL
# 1           BeryL
# 2         Lehends
# 3           BeryL
# 4           BeryL
#
# [5 rows x 35 columns]

# %%
list(df.columns[5:])
# Out:
# ['team_1_ban_1',
#  'team_1_ban_2',
#  'team_1_ban_3',
#  'team_1_ban_4',
#  'team_1_ban_5',
#  'team_2_ban_1',
#  'team_2_ban_2',
#  'team_2_ban_3',
#  'team_2_ban_4',
#  'team_2_ban_5',
#  'team_1_pick_1',
#  'team_1_pick_2',
#  'team_1_pick_3',
#  'team_1_pick_4',
#  'team_1_pick_5',
#  'team_2_pick_1',
#  'team_2_pick_2',
#  'team_2_pick_3',
#  'team_2_pick_4',
#  'team_2_pick_5',
#  'team_1_player_1',
#  'team_1_player_2',
#  'team_1_player_3',
#  'team_1_player_4',
#  'team_1_player_5',
#  'team_2_player_1',
#  'team_2_player_2',
#  'team_2_player_3',
#  'team_2_player_4',
#  'team_2_player_5']

# %% [markdown]
# Separando as colunas de bans, picks e players em datasets diferentes para aplicar transformações

# %%
df_transformed_1 = df.iloc[:, 0:14] # melt bans
df_transformed_2 = df.loc[:, ["date", "patch", "team_1", "team_2", "winner_team", 'team_1_pick_1',
 'team_1_pick_2',
 'team_1_pick_3',
 'team_1_pick_4',
 'team_1_pick_5',
 'team_2_pick_1',
 'team_2_pick_2',
 'team_2_pick_3',
 'team_2_pick_4',
 'team_2_pick_5']]
df_transformed_3 = df.loc[:,["date", "patch", "team_1", "team_2", "winner_team", 'team_1_player_1',
 'team_1_player_2',
 'team_1_player_3',
 'team_1_player_4',
 'team_1_player_5',
 'team_2_player_1',
 'team_2_player_2',
 'team_2_player_3',
 'team_2_player_4',
 'team_2_player_5']]

# %% [markdown]
# Fazendo a primeira transformação, empilhando os bans

# %%
df_1_melted = pd.melt(df_transformed_1, id_vars=["date", "patch", "team_1", "team_2", "winner_team"], value_vars=df_transformed_1.columns[5:], value_name="bans")
df_1_melted = df_1_melted.drop(columns=["variable"])
df_1_melted
# Out:
#           date  patch         team_1         team_2 winner_team          bans
# 0   2022-10-31  12.18          Gen.G            DRX         DRX  Heimerdinger
# 1   2022-10-30  12.18          Gen.G            DRX         DRX  Heimerdinger
# 2   2022-10-30  12.18            DRX          Gen.G         DRX        Lucian
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G  Heimerdinger
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX  Heimerdinger
# ..         ...    ...            ...            ...         ...           ...
# 301 2022-10-13  12.18             T1         Cloud9          T1      Renekton
# 302 2022-10-13  12.18             T1         Fnatic          T1           Jax
# 303 2022-10-10  12.18         Cloud9             T1          T1  Renata Glasc
# 304 2022-10-08  12.18         Fnatic             T1      Fnatic          Pyke
# 305 2022-10-08  12.18             T1  EDward Gaming          T1        Kennen
#
# [306 rows x 6 columns]

# %% [markdown]
# Aplicando a segunda transformação e já unindo com a primeira transformação - empilhando os picks

# %%
df_2_melted = pd.melt(df_transformed_2, id_vars=["date", "patch", "team_1", "team_2", "winner_team"],
                      value_vars=df_transformed_2.columns[5:], value_name="picks")
df_2_melted = df_2_melted.drop(columns=["variable"])
df_melted = df_1_melted.join(df_2_melted.iloc[:, -1])
df_melted
# Out:
#           date  patch         team_1         team_2 winner_team          bans  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX  Heimerdinger
# 1   2022-10-30  12.18          Gen.G            DRX         DRX  Heimerdinger
# 2   2022-10-30  12.18            DRX          Gen.G         DRX        Lucian
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G  Heimerdinger
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX  Heimerdinger
# ..         ...    ...            ...            ...         ...           ...
# 301 2022-10-13  12.18             T1         Cloud9          T1      Renekton
# 302 2022-10-13  12.18             T1         Fnatic          T1           Jax
# 303 2022-10-10  12.18         Cloud9             T1          T1  Renata Glasc
# 304 2022-10-08  12.18         Fnatic             T1      Fnatic          Pyke
# 305 2022-10-08  12.18             T1  EDward Gaming          T1        Kennen
#
#         picks
# 0    Renekton
# 1     Sejuani
# 2      Gragas
# 3       Fiora
# 4         Jax
# ..        ...
# 301    Kai'Sa
# 302    Lucian
# 303    Kai'Sa
# 304  Aphelios
# 305   Kalista
#
# [306 rows x 7 columns]

# %% [markdown]
# Aplicando a última transformação e renomeando a coluna variable para `team_player` onde será o time do jogador

# %%
df_3_melted = pd.melt(df_transformed_3, id_vars=["date", "patch", "team_1", "team_2", "winner_team"], value_vars=df_transformed_3.columns[5:],
                      value_name="players")
df_3_melted
# Out:
#           date  patch         team_1         team_2 winner_team  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX
# 1   2022-10-30  12.18          Gen.G            DRX         DRX
# 2   2022-10-30  12.18            DRX          Gen.G         DRX
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX
# ..         ...    ...            ...            ...         ...
# 335 2022-10-13  12.18             T1         Cloud9          T1
# 336 2022-10-13  12.18             T1         Fnatic          T1
# 337 2022-10-10  12.18         Cloud9             T1          T1
# 338 2022-10-08  12.18         Fnatic             T1      Fnatic
# 339 2022-10-08  12.18             T1  EDward Gaming          T1
#
#             variable    players
# 0    team_1_player_1      Doran
# 1    team_1_player_1      Doran
# 2    team_1_player_1     Kingen
# 3    team_1_player_1      Doran
# 4    team_1_player_1    Flandre
# ..               ...        ...
# 335  team_2_player_5       Zven
# 336  team_2_player_5  Hylissang
# 337  team_2_player_5      Keria
# 338  team_2_player_5      Keria
# 339  team_2_player_5      Meiko
#
# [340 rows x 7 columns]

# %%
df_3_melted = df_3_melted.rename(columns={"variable": "team_player"})
df_3_melted
# Out:
#           date  patch         team_1         team_2 winner_team  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX
# 1   2022-10-30  12.18          Gen.G            DRX         DRX
# 2   2022-10-30  12.18            DRX          Gen.G         DRX
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX
# ..         ...    ...            ...            ...         ...
# 335 2022-10-13  12.18             T1         Cloud9          T1
# 336 2022-10-13  12.18             T1         Fnatic          T1
# 337 2022-10-10  12.18         Cloud9             T1          T1
# 338 2022-10-08  12.18         Fnatic             T1      Fnatic
# 339 2022-10-08  12.18             T1  EDward Gaming          T1
#
#          team_player    players
# 0    team_1_player_1      Doran
# 1    team_1_player_1      Doran
# 2    team_1_player_1     Kingen
# 3    team_1_player_1      Doran
# 4    team_1_player_1    Flandre
# ..               ...        ...
# 335  team_2_player_5       Zven
# 336  team_2_player_5  Hylissang
# 337  team_2_player_5      Keria
# 338  team_2_player_5      Keria
# 339  team_2_player_5      Meiko
#
# [340 rows x 7 columns]

# %% [markdown]
# Nessa transformação/imputação de dados iremos seguir a seguinte lógica: <br>
# * Se team_player tem alguma string "team_1" iremos colocar o nome do time que está na coluna "team_1"
# * Se team_player tem alguma string "team_2" colocaremos o nome do time do "team_2"

# %%
has_team_1 = df_3_melted["team_player"].str.contains(r'^team_1.*')
has_team_2 = df_3_melted["team_player"].str.contains(r'^team_2.*')

# %%
has_team_2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 335     True
# 336     True
# 337     True
# 338     True
# 339     True
# Name: team_player, Length: 340, dtype: bool

# %% [markdown]
# Colocando o nome do time de cada player, e verificando se está correto <br>
# como por exemplo: Doran pertence a time da Gen.G que está na coluna `team_1` <br>
# Kingen pertence a DRX<br>
# Porém ainda não definimos os players que estão no `team_2`

# %%
df_3_melted.loc[has_team_1, "team_player"] = df_3_melted.team_1

# %%
df_3_melted
# Out:
#           date  patch         team_1         team_2 winner_team  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX
# 1   2022-10-30  12.18          Gen.G            DRX         DRX
# 2   2022-10-30  12.18            DRX          Gen.G         DRX
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX
# ..         ...    ...            ...            ...         ...
# 335 2022-10-13  12.18             T1         Cloud9          T1
# 336 2022-10-13  12.18             T1         Fnatic          T1
# 337 2022-10-10  12.18         Cloud9             T1          T1
# 338 2022-10-08  12.18         Fnatic             T1      Fnatic
# 339 2022-10-08  12.18             T1  EDward Gaming          T1
#
#          team_player    players
# 0              Gen.G      Doran
# 1              Gen.G      Doran
# 2                DRX     Kingen
# 3              Gen.G      Doran
# 4      EDward Gaming    Flandre
# ..               ...        ...
# 335  team_2_player_5       Zven
# 336  team_2_player_5  Hylissang
# 337  team_2_player_5      Keria
# 338  team_2_player_5      Keria
# 339  team_2_player_5      Meiko
#
# [340 rows x 7 columns]

# %% [markdown]
# Fazendo a mesma transformação para os players que estão nos times da coluna `team_2`

# %%
df_3_melted.loc[has_team_2, "team_player"] = df_3_melted.team_2

# %%
df_3_melted
# Out:
#           date  patch         team_1         team_2 winner_team  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX
# 1   2022-10-30  12.18          Gen.G            DRX         DRX
# 2   2022-10-30  12.18            DRX          Gen.G         DRX
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX
# ..         ...    ...            ...            ...         ...
# 335 2022-10-13  12.18             T1         Cloud9          T1
# 336 2022-10-13  12.18             T1         Fnatic          T1
# 337 2022-10-10  12.18         Cloud9             T1          T1
# 338 2022-10-08  12.18         Fnatic             T1      Fnatic
# 339 2022-10-08  12.18             T1  EDward Gaming          T1
#
#        team_player    players
# 0            Gen.G      Doran
# 1            Gen.G      Doran
# 2              DRX     Kingen
# 3            Gen.G      Doran
# 4    EDward Gaming    Flandre
# ..             ...        ...
# 335         Cloud9       Zven
# 336         Fnatic  Hylissang
# 337             T1      Keria
# 338             T1      Keria
# 339  EDward Gaming      Meiko
#
# [340 rows x 7 columns]

# %% [markdown]
# Verificando o dataset transformado com as colunas bans e picks

# %%
df_melted
# Out:
#           date  patch         team_1         team_2 winner_team          bans  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX  Heimerdinger
# 1   2022-10-30  12.18          Gen.G            DRX         DRX  Heimerdinger
# 2   2022-10-30  12.18            DRX          Gen.G         DRX        Lucian
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G  Heimerdinger
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX  Heimerdinger
# ..         ...    ...            ...            ...         ...           ...
# 301 2022-10-13  12.18             T1         Cloud9          T1      Renekton
# 302 2022-10-13  12.18             T1         Fnatic          T1           Jax
# 303 2022-10-10  12.18         Cloud9             T1          T1  Renata Glasc
# 304 2022-10-08  12.18         Fnatic             T1      Fnatic          Pyke
# 305 2022-10-08  12.18             T1  EDward Gaming          T1        Kennen
#
#         picks
# 0    Renekton
# 1     Sejuani
# 2      Gragas
# 3       Fiora
# 4         Jax
# ..        ...
# 301    Kai'Sa
# 302    Lucian
# 303    Kai'Sa
# 304  Aphelios
# 305   Kalista
#
# [306 rows x 7 columns]

# %% [markdown]
# Unindo todas as colunas transformadas e vendo nosso dataset final

# %%
df_melted = df_melted.join(df_3_melted.iloc[:, -2:])

# %%
df_melted
# Out:
#           date  patch         team_1         team_2 winner_team          bans  \
# 0   2022-10-31  12.18          Gen.G            DRX         DRX  Heimerdinger
# 1   2022-10-30  12.18          Gen.G            DRX         DRX  Heimerdinger
# 2   2022-10-30  12.18            DRX          Gen.G         DRX        Lucian
# 3   2022-10-30  12.18          Gen.G            DRX       Gen.G  Heimerdinger
# 4   2022-10-24  12.18  EDward Gaming            DRX         DRX  Heimerdinger
# ..         ...    ...            ...            ...         ...           ...
# 301 2022-10-13  12.18             T1         Cloud9          T1      Renekton
# 302 2022-10-13  12.18             T1         Fnatic          T1           Jax
# 303 2022-10-10  12.18         Cloud9             T1          T1  Renata Glasc
# 304 2022-10-08  12.18         Fnatic             T1      Fnatic          Pyke
# 305 2022-10-08  12.18             T1  EDward Gaming          T1        Kennen
#
#         picks    team_player    players
# 0    Renekton          Gen.G      Doran
# 1     Sejuani          Gen.G      Doran
# 2      Gragas            DRX     Kingen
# 3       Fiora          Gen.G      Doran
# 4         Jax  EDward Gaming    Flandre
# ..        ...            ...        ...
# 301    Kai'Sa         Cloud9  Berserker
# 302    Lucian         Fnatic      Upset
# 303    Kai'Sa             T1   Gumayusi
# 304  Aphelios             T1   Gumayusi
# 305   Kalista  EDward Gaming      Viper
#
# [306 rows x 9 columns]

# %% [markdown]
# Exportando para CSV para futura análise

# %%
df_melted.to_csv("match_history_teams.csv", index=False)
